# %% [markdown]
# # Unsupervised 2D Seismic Data Reconstruction Based On Deep Prior
#
# [Fantong Kong](mailto:kft_upc@hotmail.com)<sup>1</sup>,
# [Francesco Picetti](mailto:francesco.picetti@polimi.it)<sup>2</sup>,
# Vincenzo Lipari<sup>2</sup>, Paolo Bestagini<sup>2</sup>,
# Xiaoming Tang<sup>1</sup>, and Stefano Tubaro<sup>2</sup>
#
# 1: School of Geosciences - China University of Petroleum (East), Qingdao, China<br>
# 2: Dipartimento di Elettronica, Informazione e Bioingegneria - Politecnico di Milano, Italy

# %% [markdown]
# In this notebook we show our 2D MultiRes UNet workflow for irregular data interpolation on a synthetic 2D dataset that shows simple linear events.

# %%
from __future__ import print_function
import warnings
warnings.filterwarnings("ignore")
import os
import torch
import numpy as np
from argparse import Namespace
from termcolor import colored

from main import Interpolator
import utils as u
from data import extract_patches

import matplotlib.pyplot as plt
from matplotlib import rcParams
params = {
    'image.cmap': 'gray',
    'axes.grid': False,
    'savefig.dpi': 300,  # to adjust notebook inline plot size
    'axes.labelsize': 14, # fontsize for x and y labels (was 10)
    'axes.titlesize': 14,
    'font.size': 14,
    'legend.fontsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'text.usetex':True
}
rcParams.update(params)

# %%
print(np.__version__)
# Out:
# 1.24.3

# %% [markdown]
# ### Parameters

# %%
args = Namespace(
    gpu=1,
    # problem data
    imgdir = '/home/jbgpl/seismic_DL/interpolation/deep_prior_interpolation-master/datasets/pohang/observed/',  # original data path
    outdir = './results/',                  # interpolation data path
    imgname = 'observed76_1.npy', # original path
    maskname = 'noise2_1500_76.npy',       # cutting data
    netdir = None,
    gain = 1.,
    datadim = '2d',
    slice="tx",
    imgchannel=1,
    patch_shape=[-1,-1,-1],
    patch_stride=[-1,-1,-1],
    # architecture
    net = " multiunet",
    activation='LeakyReLU',
    last_activation=None,
    dropout=0.,
    filters=[16, 32, 64, 128, 256],
    skip=[16, 32, 64, 128],
    inputdepth=64,
    noise_dist='n',
    noise_std=.1,
    upsample='bilinear',
    inittype='xavier',
    initgain=0.02,
    filter_noise_with_wavelet=False,
    lowpass_fs=None,
    lowpass_fc=None,
    # optimization and schedulers
    loss="mse",
    epochs=500,      # 1000~5000
    lr=1e-4,          # 1e-3,1e-4
    data_forgetting_factor=0,
    start_from_prev=False,
    pocs_weight=None,
    reduce_lr=False,
    lr_factor=0.9,
    lr_thresh=1e-5,
    lr_patience=100,
    savemodel=False,
    save_every=10000,
    loss_max=30.,
    param_noise=False,
    reg_noise_std=0.03,
    adirandel=0,
    earlystop_patience=10000,
    earlystop_min_delta=1.,
)

# %% [markdown]
# ## Inverse Problem
#
# The Training class is the actual optimization problem
#
# \begin{equation}
#     \theta^* = \arg \min_\theta \Vert \mathbf{S} f_\theta(\mathbf{z}) - \mathbf{d}_\text{obs}\Vert_1,
# \end{equation}
#
# where $\mathbf{S}$ is the sampling operator we want to invert,
# $\mathbf{d}_\text{obs}$ are the acquired coarse and/or irregular data,
# $\mathbf{z}$ is a noise tensor that is input of the network,
# $f$ is the CNN and $\theta$ its parameters.
#
# The interpolated data are the output of the optimized network: $\mathbf{m}^* = f_{\theta^*}(\mathbf{z})$.

# %%
# set the engine to be used
u.set_gpu(args.gpu)
u.set_seed()

# %%
# create output folder
dir_list = list(filter(None, args.imgdir.split('/')))
outpath = os.path.join(args.outdir, 'notebook_2d')
os.makedirs(outpath, exist_ok=True)
print(colored('Saving to %s' % outpath, 'yellow'))
# Out:
# Saving to ./results/notebook_2d

# %%
T = Interpolator(args, outpath)

# %% [markdown]
# ### Load data

# %% [markdown]
# We subdivide the dataset in 3D patches in order to keep the GPU memory usage low.

# %%
patches_list = extract_patches(args)

# %%
patch = patches_list[0]

opt = dict(cmap="gray", clim=u.clim(patch["image"], 98), aspect='auto')

# %% [markdown]
# Need install LaTex
# 실행이 안되면
# Anaconda prompt 관리자 권한으로 실행 -> conda install -c conda-forge miktex

# %%
plt.figure(figsize=(14,6),facecolor='w')
plt.subplot(131), plt.title('True model')
plt.imshow(patch['image'].squeeze(), **opt)
plt.subplot(132), plt.title('Sampling operator')
plt.imshow(patch['mask'].squeeze(), aspect='auto')
plt.subplot(133), plt.title('Observed data')
plt.imshow((patch['image']*patch['mask']).squeeze(), **opt)
# plt.subplot(144), plt.title('Reconstructed model')
# plt.imshow((patch['image']-(patch['image']*patch['mask'])).squeeze(), **opt)
plt.show()

# %% [markdown]
# ### Optimization

# %%
for patch in patches_list:

    print(colored('\nThe data shape is %s' % str(patch['image'].shape), 'cyan'))

    std = T.load_data(patch)
    print(colored('the std of coarse data is %.2e, ' % std, 'cyan'), end="")

    if np.isclose(std, 0., atol=1e-12):  # all the data are corrupted
        print(colored('skipping...', 'cyan'))
        T.out_best = T.img# * T.mask
        T.elapsed = 0.
    else:
        if T.net is None or not args.start_from_prev:
            if args.net == "load":
                T.build_model(netpath=args.netdir[i])
            else:
                T.build_model()
        T.build_input()
        T.optimize()

    T.save_result()
    T.clean()

print(colored('Interpolation done!', 'yellow'))
# Out:
# The data shape is (1500, 76, 1)
# the std of coarse data is 1.94e+00, The input shape is (1, 64, 1500, 76)
# starting optimization with ADAM...
# Iter 102, Loss = +2.10e-01, SNR = +1.61 dB, PCORR = +57.73 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jbgpl/seismic_DL/interpolation/deep_prior_interpolation-master/proof_of_concept_2D.ipynb Cell 20 in <cell line: 1>()
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22576f726b73746174696f6e323335227d/home/jbgpl/seismic_DL/interpolation/deep_prior_interpolation-master/proof_of_concept_2D.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a>             T.build_model()
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22576f726b73746174696f6e323335227d/home/jbgpl/seismic_DL/interpolation/deep_prior_interpolation-master/proof_of_concept_2D.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>     T.build_input()
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22576f726b73746174696f6e323335227d/home/jbgpl/seismic_DL/interpolation/deep_prior_interpolation-master/proof_of_concept_2D.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a>     T.optimize()
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22576f726b73746174696f6e323335227d/home/jbgpl/seismic_DL/interpolation/deep_prior_interpolation-master/proof_of_concept_2D.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> T.save_result()
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22576f726b73746174696f6e323335227d/home/jbgpl/seismic_DL/interpolation/deep_prior_interpolation-master/proof_of_concept_2D.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a> T.clean()
#
# File ~/seismic_DL/interpolation/deep_prior_interpolation-master/main.py:218, in Interpolator.optimize(self)
#     216 for j in range(self.args.epochs):
#     217     self.optimizer.zero_grad()
# --> 218     loss = self.optimization_loop()
#     219     self.optimizer.step()
#     220     if self.args.reduce_lr:
#
# File ~/seismic_DL/interpolation/deep_prior_interpolation-master/main.py:168, in Interpolator.optimization_loop(self)
#     166 # compute the loss function
#     167 total_loss = self.loss_fn(out_ * self.mask_, self.img_ * self.mask_)
# --> 168 total_loss.backward()
#     170 # save loss and metrics, and print log
#     171 l = total_loss.item()
#
# File /APP/anaconda3/envs/geoai/lib/python3.10/site-packages/torch/_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File /APP/anaconda3/envs/geoai/lib/python3.10/site-packages/torch/autograd/__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Results Evaluation

# %%
run = np.load(os.path.join(outpath, '0_run.npy'), allow_pickle=True).item()
#run = np.load(os.path.join('./results/TL/shot', '0_run.npy'), allow_pickle=True).item()

# %%
run.keys()
# Out:
# dict_keys(['device', 'elapsed', 'outpath', 'history', 'mask', 'image', 'output', 'noise'])

# %%
output = run['output']
np.save('./results/sleipner.npy',output)

# %%
patch = patches_list[0]

normalized_squared_error = (patch['image'] - output)**2 / np.max(np.abs(patch['image']))**2

plt.figure(figsize=(14,6))
plt.subplot(131), plt.title('True model')
plt.imshow(patch['image'].squeeze(), **opt), plt.colorbar()
plt.subplot(132), plt.title('Reconstructed model')
plt.imshow(output.squeeze(),**opt), plt.colorbar()
plt.subplot(133), plt.title('Residual')
plt.imshow(normalized_squared_error.squeeze()*1000,**opt), plt.colorbar()
plt.show()

# %% [markdown]
# ### Check optimization objective function

# %%
plt.figure(figsize=(17,3))
plt.title('Objective Function')
plt.semilogy(run['history'].loss)
plt.grid(True), plt.xlim(0, args.epochs), plt.ylim(0, 2)

plt.figure(figsize=(17,3))
plt.title('SNR')
plt.plot(run['history'].snr)
plt.grid(True), plt.xlim(0, args.epochs), plt.ylim(0,20)

plt.figure(figsize=(17,3))
plt.title('P-Corr')
plt.plot(np.abs(run['history'].pcorr))
plt.grid(True), plt.xlabel('iteration'), plt.xlim(0, args.epochs), plt.ylim(0, 1)
plt.show()
